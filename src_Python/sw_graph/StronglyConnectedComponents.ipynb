# %% [markdown]
# # Strongly connected components
#
#  Strongly Connected Components using DFS, topological sort

# %%
# %pwd
import BasicGraph
# %run BasicGraph.py
# Out:
# hi! I'm BasicGraph.py file

# %%
def DFS(G, a = []): # a = [] 이면 순서를 dict.keys() 순으로, o.w list (a)  순으로 searching 
    
    # running time O(V + E)
    
    for u in list(G.graph_dict.keys()):   
        G.nm[u].color = 'white'
        G.nm[u].pi = None
        
    G.time = 0
    
    print("Debug sorting ", a)
    if a == []:
        print(G.graph_dict.keys()," 순으로 searching 하게 된다.")
        for u in list(G.graph_dict.keys()): 
            if G.nm[u].color == 'white':
                DFS_visit(G,u)
    else:
        print(a," 순으로 searching 하게 된다.")
        for u in a: 
            if G.nm[u].color == 'white':
                DFS_visit(G,u)
    
    for x in list(G.graph_dict.keys()):
        print("vertex name: ", G.nm[x].name)
        print("color 값: ", G.nm[x].color)
        print("d 값: ", G.nm[x].d)
        print("f 값: ", G.nm[x].f)
        print("pi 값: ", G.nm[x].pi)
    
    
def DFS_visit(G,u):
    G.time  = G.time + 1 
    G.nm[u].d = G.time 
    G.nm[u].color = 'gray'
    
    print(G.graph_dict[u] ," 순으로 vertex", u, " 의 adjoint list를 searching 하게 된다.")
    for v in list(G.graph_dict[u]):
        if G.nm[v].color == 'white':
            G.nm[v].pi  = u
            DFS_visit(G,v)
    G.nm[u].color = 'black'
    G.time = G.time + 1 
    G.nm[u].f = G.time    
    
    
    
import operator

# graph 에서 모든 edge들의 우선순위를 지켜주는 linear ordering 을 찾아 주었다. 
# DAG(directed Acyclic graph) 에서 사용 
def Topological_sort(G,l = []):
    
    print("Topological_sort사용")
    DFS(G,l)
    
    #print(G.nodes) 
    #print(G.nm)

    # node object로 dictionary 만듦a
    topo = {}
    for k in range(len(list(G.graph_dict.keys()))):
        topo[G.nodes[k].name] = G.nodes[k].f
    
    print(topo, "topo값 ")
    temp = sorted(topo.items(), key = operator.itemgetter(1), reverse = True)
    print(temp, "temp 길이 ", len(temp),"sort 이후 ")
    
    srt = []
    for m in range(0,len(temp)):
        srt.append(temp[m][0])
    
    print(srt, "Topological sort 결과 ")
    
    return srt

# %%
def Transpose(G):
    gt = {}
    
    for i in list(G.graph_dict.keys()):   # initialize gt dictionary 
        gt[i] = set()
    
    #print(gt)
        
    for vertex in list(G.graph_dict.keys()):
        #print(vertex,"debug1")
        for ev in list(G.graph_dict[vertex]):
            #print(ev,"debug2", G.graph_dict[vertex])
            for vt in list(G.graph_dict.keys()):
                #print(vt,"debug3", G.graph_dict.keys())
                if vt == ev:
                    #print([vertex,ev,vt])
                    gt[ev].update(vertex)
                    #print(gt)
    return Graph(gt)

# %%
def SCC(G):
    
    print("G 에 대해서 DFS (.f, .d 를 구함)")
    DFS(G)
    Gt = Transpose(G)
    
    print("Gt 에 대해서 topological sort 순으로 vertex searching하여  DFS SCC 구하기 위해")
    a = Topological_sort(G)
    DFS(Gt, a)
    
    print("완료")
    
    print(" predecessor 가 결정 되지 않은 independent tree를 형성한 것들이 Strongly Connected Components를 의미 ")

# %%
g = {'a': set(['b']),
     'b': set(['c','e','f']),
     'c': set(['d', 'g']),
     'd': set(['c','h']),
     'e': set(['a','f']),
     'f': set(['g']),
     'g': set(['f','h']),
     'h': set(['h'])}

G = Graph(g)
SCC(G)
# Out:
# G 에 대해서 DFS (.f, .d 를 구함)
# Debug sorting  []
# dict_keys(['g', 'h', 'c', 'd', 'b', 'e', 'a', 'f'])  순으로 searching 하게 된다.
# {'h', 'f'}  순으로 vertex g  의 adjoint list를 searching 하게 된다.
# {'h'}  순으로 vertex h  의 adjoint list를 searching 하게 된다.
# {'g'}  순으로 vertex f  의 adjoint list를 searching 하게 된다.
# {'g', 'd'}  순으로 vertex c  의 adjoint list를 searching 하게 된다.
# {'h', 'c'}  순으로 vertex d  의 adjoint list를 searching 하게 된다.
# {'e', 'c', 'f'}  순으로 vertex b  의 adjoint list를 searching 하게 된다.
# {'a', 'f'}  순으로 vertex e  의 adjoint list를 searching 하게 된다.
# {'b'}  순으로 vertex a  의 adjoint list를 searching 하게 된다.
# vertex name:  g
# color 값:  black
# d 값:  1
# f 값:  6
# pi 값:  None
# vertex name:  h
# color 값:  black
# d 값:  2
# f 값:  3
# pi 값:  g
# vertex name:  c
# color 값:  black
# d 값:  7
# f 값:  10
# pi 값:  None
# vertex name:  d
# color 값:  black
# d 값:  8
# f 값:  9
# pi 값:  c
# vertex name:  b
# color 값:  black
# d 값:  11
# f 값:  16
# pi 값:  None
# vertex name:  e
# color 값:  black
# d 값:  12
# f 값:  15
# pi 값:  b
# vertex name:  a
# color 값:  black
# d 값:  13
# f 값:  14
# pi 값:  e
# vertex name:  f
# color 값:  black
# d 값:  4
# f 값:  5
# pi 값:  g
# Gt 에 대해서 topological sort 순으로 vertex searching하여  DFS SCC 구하기 위해
# Topological_sort사용
# Debug sorting  []
# dict_keys(['g', 'h', 'c', 'd', 'b', 'e', 'a', 'f'])  순으로 searching 하게 된다.
# {'h', 'f'}  순으로 vertex g  의 adjoint list를 searching 하게 된다.
# {'h'}  순으로 vertex h  의 adjoint list를 searching 하게 된다.
# {'g'}  순으로 vertex f  의 adjoint list를 searching 하게 된다.
# {'g', 'd'}  순으로 vertex c  의 adjoint list를 searching 하게 된다.
# {'h', 'c'}  순으로 vertex d  의 adjoint list를 searching 하게 된다.
# {'e', 'c', 'f'}  순으로 vertex b  의 adjoint list를 searching 하게 된다.
# {'a', 'f'}  순으로 vertex e  의 adjoint list를 searching 하게 된다.
# {'b'}  순으로 vertex a  의 adjoint list를 searching 하게 된다.
# vertex name:  g
# color 값:  black
# d 값:  1
# f 값:  6
# pi 값:  None
# vertex name:  h
# color 값:  black
# d 값:  2
# f 값:  3
# pi 값:  g
# vertex name:  c
# color 값:  black
# d 값:  7
# f 값:  10
# pi 값:  None
# vertex name:  d
# color 값:  black
# d 값:  8
# f 값:  9
# pi 값:  c
# vertex name:  b
# color 값:  black
# d 값:  11
# f 값:  16
# pi 값:  None
# vertex name:  e
# color 값:  black
# d 값:  12
# f 값:  15
# pi 값:  b
# vertex name:  a
# color 값:  black
# d 값:  13
# f 값:  14
# pi 값:  e
# vertex name:  f
# color 값:  black
# d 값:  4
# f 값:  5
# pi 값:  g
# {'g': 6, 'h': 3, 'c': 10, 'd': 9, 'b': 16, 'e': 15, 'a': 14, 'f': 5} topo값
# [('b', 16), ('e', 15), ('a', 14), ('c', 10), ('d', 9), ('g', 6), ('f', 5), ('h', 3)] temp 길이  8 sort 이후
# ['b', 'e', 'a', 'c', 'd', 'g', 'f', 'h'] Topological sort 결과
# Debug sorting  ['b', 'e', 'a', 'c', 'd', 'g', 'f', 'h']
# ['b', 'e', 'a', 'c', 'd', 'g', 'f', 'h']  순으로 searching 하게 된다.
# {'a'}  순으로 vertex b  의 adjoint list를 searching 하게 된다.
# {'e'}  순으로 vertex a  의 adjoint list를 searching 하게 된다.
# {'b'}  순으로 vertex e  의 adjoint list를 searching 하게 된다.
# {'d', 'b'}  순으로 vertex c  의 adjoint list를 searching 하게 된다.
# {'c'}  순으로 vertex d  의 adjoint list를 searching 하게 된다.
# {'c', 'f'}  순으로 vertex g  의 adjoint list를 searching 하게 된다.
# {'g', 'e', 'b'}  순으로 vertex f  의 adjoint list를 searching 하게 된다.
# {'g', 'h', 'd'}  순으로 vertex h  의 adjoint list를 searching 하게 된다.
# vertex name:  g
# color 값:  black
# d 값:  11
# f 값:  14
# pi 값:  None
# vertex name:  h
# color 값:  black
# d 값:  15
# f 값:  16
# pi 값:  None
# vertex name:  c
# color 값:  black
# d 값:  7
# f 값:  10
# pi 값:  None
# vertex name:  d
# color 값:  black
# d 값:  8
# f 값:  9
# pi 값:  c
# vertex name:  b
# color 값:  black
# d 값:  1
# f 값:  6
# pi 값:  None
# vertex name:  e
# color 값:  black
# d 값:  3
# f 값:  4
# pi 값:  a
# vertex name:  a
# color 값:  black
# d 값:  2
# f 값:  5
# pi 값:  b
# vertex name:  f
# color 값:  black
# d 값:  12
# f 값:  13
# pi 값:  g
# 완료
#  predecessor 가 결정 되지 않은 independent tree를 형성한 것들이 Strongly Connected Components를 의미
